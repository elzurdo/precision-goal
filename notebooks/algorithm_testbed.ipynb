# %%
# IPython extension to reload modules before executing user code.
# useful to see immediate results in notebook when modifying imported scripts
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os
import numpy as np
import pandas as pd

# Add the ../py directory to sys.path
# This allows importing modules from the py directory as if they were in the current directory
module_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'py'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Verify it works
print(f"Added to path: {module_path}")
# Out:
# Added to path: /Users/eyal/projects/elzurdo/precision-goal/py

# %%
import sys
import os
import numpy as np
import pytest

from utils_experiments import (
    stop_decision_multiple_experiments_multiple_methods,
    BinomialSimulation,
    BinomialHypothesis,
    BinaryAccounting,
    create_decision_correctness_df
    )

from utils_stats import continuous_hdi_ci_limits

# %% [markdown]
# # HDI Calculations

# %% [markdown]
# ## Binomial

# %% [markdown]
# ## Continuous

# %%
# Example: mean=100, std=15, n=30
hdi_min, hdi_max = continuous_hdi_ci_limits(100, 15, 30)
print(f"95% HDI: [{hdi_min:.2f}, {hdi_max:.2f}]")
print(f"HDI width: {hdi_max - hdi_min:.2f}")
# Out:
# 95% HDI: [94.40, 105.60]
# HDI width: 11.20

# %%
pdf = beta.pdf(pp, successes, failures)

# %% [markdown]
# Visualisation idea:
# * data distribution
# * Parameter values

# %% [markdown]
# # `stop_decision_multiple_experiments_multiple_methods`

# %% [markdown]
# ## Hand Picked

# %%
n_experiments = 1
n_samples = 810  # this is long enough to see the differences between the three methods.

sequence_ = "..."
sequence_ = sequence_[:n_samples]  # Truncate to n_samples

len(sequence_)
# Out:
# 810

# %%
samples = np.zeros((n_experiments, n_samples), dtype=int)
samples[0] = [int(bit) for bit in sequence_]

# %%
# Define parameters (as used in paper)
rope_min = 0.45
rope_max = 0.55
precision_goal = 0.08
min_iter = 30

# Run the function
# Note: binary_accounting is optional, skipping for simplicity in this basic test
method_stats, method_roperesult_iteration = stop_decision_multiple_experiments_multiple_methods(
    samples, 
    rope_min=rope_min, 
    rope_max=rope_max, 
    precision_goal=precision_goal,
    min_iter=min_iter,
    viz=False
)

# %%
method_stats.keys()
# Out:
# dict_keys(['pitg', 'epitg', 'hdi_rope'])

# %%
# Check if keys exist
assert 0 in method_stats['pitg'], "Experiment 0 missing from PitG stats"
assert 0 in method_stats['epitg'], "Experiment 0 missing from ePitG stats"
assert 0 in method_stats['hdi_rope'], "Experiment 0 missing from HDI+ROPE stats"

# %%
pitg_res = method_stats['pitg'][0]
epitg_res = method_stats['epitg'][0]
hdi_rope_res = method_stats['hdi_rope'][0]

# %%
# Consistency checks
assert pitg_res['precision_goal_achieved'] == True, "PitG should have achieved precision goal"
assert pitg_res['hdi_max'] - pitg_res['hdi_min'] < precision_goal, "Calculated precision should be < goal"

assert epitg_res['decision_iteration'] >= pitg_res['decision_iteration'], "ePitG should not stop before PitG"

# %%
# Asserting known values
assert hdi_rope_res["decision_iteration"] == 126
assert hdi_rope_res["reject_above"] == True

assert pitg_res["decision_iteration"] == 598
assert pitg_res["inconclusive"] == True

assert epitg_res["decision_iteration"] == 804
assert epitg_res["accept"] == True

# %%
method_stats['hdi_rope']
# Out:
# {0: {'decision_iteration': 126,
#   'accept': False,
#   'reject_below': False,
#   'reject_above': True,
#   'conclusive': True,
#   'inconclusive': False,
#   'successes': 80,
#   'failures': 46,
#   'hdi_min': 0.5508244626218101,
#   'hdi_max': 0.717876210358378,
#   'precision_goal_achieved': False}}

# %%
method_stats['pitg']
# Out:
# {0: {'decision_iteration': 598,
#   'accept': False,
#   'reject_below': False,
#   'reject_above': False,
#   'conclusive': False,
#   'inconclusive': True,
#   'successes': 314,
#   'failures': 284,
#   'hdi_min': 0.4850822706487851,
#   'hdi_max': 0.5650347292260883,
#   'precision_goal_achieved': True}}

# %%
method_stats['epitg']
# Out:
# {0: {'decision_iteration': 804,
#   'accept': True,
#   'reject_below': False,
#   'reject_above': False,
#   'conclusive': True,
#   'inconclusive': False,
#   'successes': 414,
#   'failures': 390,
#   'hdi_min': 0.4803983603190735,
#   'hdi_max': 0.5494290170209941,
#   'precision_goal_achieved': True}}

# %% [markdown]
# ## Multiple Sequences

# %%
true_rate = 0.57
N_SAMPLES = 1500
N_EXPERIMENTS = 3
SEED = 42

synth_0pt5 = BinomialSimulation(
    success_rate=true_rate,
    n_samples = N_SAMPLES,
    n_experiments = N_EXPERIMENTS,
    seed=SEED)
# Out:
# Generating synthetic data with parameter values:
# 0.57: true success rate
# 3: experiments
# 1500: sample size per experiment

# %%
# %%time

method_stats, method_roperesult_iteration = stop_decision_multiple_experiments_multiple_methods(
    synth_0pt5.experiments, 
    rope_min=rope_min, 
    rope_max=rope_max, 
    precision_goal=precision_goal,
    min_iter=min_iter,
    viz=False
)
# Out:
# CPU times: user 20.9 s, sys: 63.9 ms, total: 20.9 s
# Wall time: 21 s

# %%
method_stats['epitg'][0]
# Out:
# {'decision_iteration': 1500,
#  'accept': False,
#  'reject_below': False,
#  'reject_above': False,
#  'conclusive': False,
#  'inconclusive': True,
#  'successes': 840,
#  'failures': 660,
#  'hdi_min': 0.534867547044455,
#  'hdi_max': 0.5850835156227976,
#  'precision_goal_achieved': True}

# %%
df_experiment_correctness = create_decision_correctness_df(method_stats, true_rate, rope_min, rope_max)

df_experiment_correctness.head(4)
# Out:
#                hdi_rope_decision_iteration hdi_rope_accept  \
# experiment_idx
# 0                                     1500           False
# 1                                     1500           False
# 2                                     1500           False
#
#                hdi_rope_reject_below hdi_rope_reject_above  \
# experiment_idx
# 0                              False                 False
# 1                              False                 False
# 2                              False                 False
#
#                hdi_rope_inconclusive hdi_rope_success_rate  \
# experiment_idx
# 0                               True                  0.56
# 1                               True              0.568667
# 2                               True              0.572667
#
#                hdi_rope_decision_correct pitg_decision_iteration pitg_accept  \
# experiment_idx
# 0                                   True                     593       False
# 1                                   True                     584       False
# 2                                   True                     592       False
#
#                pitg_reject_below  ... pitg_inconclusive pitg_success_rate  \
# experiment_idx                    ...
# 0                          False  ...              True           0.55312
# 1                          False  ...              True          0.578767
# 2                          False  ...              True          0.554054
#
#                pitg_decision_correct epitg_decision_iteration epitg_accept  \
# experiment_idx
# 0                               True                     1500        False
# 1                               True                     1500        False
# 2                               True                     1500        False
#
#                epitg_reject_below epitg_reject_above epitg_inconclusive  \
# experiment_idx
# 0                           False              False               True
# 1                           False              False               True
# 2                           False              False               True
#
#                epitg_success_rate epitg_decision_correct
# experiment_idx
# 0                            0.56                   True
# 1                        0.568667                   True
# 2                        0.572667                   True
#
# [3 rows x 21 columns]

# %%
df_experiment_correctness[['hdi_rope_decision_correct', 'pitg_decision_correct', 'epitg_decision_correct']]
# Out:
#                hdi_rope_decision_correct pitg_decision_correct  \
# experiment_idx
# 0                                   True                  True
# 1                                   True                  True
# 2                                   True                  True
#
#                epitg_decision_correct
# experiment_idx
# 0                                True
# 1                                True
# 2                                True

# %% [markdown]
# # Abstract Methods

# %%
null_rate = 0.5
dsuccess_rate = 0.05
rope_precision_fraction = 0.8

hypothesis_ = BinomialHypothesis(
    success_rate_null=null_rate, 
    dsuccess_rate=dsuccess_rate, 
    rope_precision_fraction=rope_precision_fraction)
# Out:
# 0.5: null hypothesis
# 0.45: ROPE min
# 0.55: ROPE max
# --------------------
# 0.08: Precision Goal

# %%
true_rate = 0.57
N_SAMPLES = 1500
N_EXPERIMENTS = 100
SEED = 42

synth_data = BinomialSimulation(
    success_rate=true_rate,
    n_samples = N_SAMPLES,
    n_experiments = N_EXPERIMENTS,
    seed=SEED)
# Out:
# Generating synthetic data with parameter values:
# 0.57: true success rate
# 100: experiments
# 1500: sample size per experiment

# %%
binary_accounting = BinaryAccounting()
binary_accounting

# %%
# %%time
hypothesis_.run_hypothesis_on_experiments(synth_data.experiments, binary_accounting)
# Out:
#           accept  reject  conclusive  inconclusive  stop_iter_mean  \
# hdi_rope     0.0    0.58        0.58          0.42          819.72
# pitg         0.0    0.20        0.20          0.80          586.28
# epitg        0.0    0.47        0.47          0.53         1138.68
#
#           stop_iter_std  success_rate_mean  success_rate_std
# hdi_rope     642.815525           0.606467          0.057314
# pitg           7.334821           0.570501          0.021422
# epitg        415.215993           0.574840          0.018304
# CPU times: user 3min 38s, sys: 529 ms, total: 3min 38s
# Wall time: 3min 40s

# %%
hypothesis_.decision_correctness(true_rate)
hypothesis_.df_experiment_correctness
# Out:
#                hdi_rope_decision_iteration hdi_rope_accept  \
# experiment_idx
# 0                                     1500           False
# 1                                     1500           False
# 2                                     1500           False
# 3                                      834           False
# 4                                      165           False
# ...                                    ...             ...
# 95                                    1500           False
# 96                                      40           False
# 97                                      30           False
# 98                                    1394           False
# 99                                    1500           False
#
#                hdi_rope_reject_below hdi_rope_reject_above  \
# experiment_idx
# 0                              False                 False
# 1                              False                 False
# 2                              False                 False
# 3                              False                  True
# 4                              False                  True
# ...                              ...                   ...
# 95                             False                 False
# 96                             False                  True
# 97                             False                  True
# 98                             False                  True
# 99                             False                 False
#
#                hdi_rope_inconclusive hdi_rope_success_rate  \
# experiment_idx
# 0                               True                  0.56
# 1                               True              0.568667
# 2                               True              0.572667
# 3                              False              0.583933
# 4                              False              0.624242
# ...                              ...                   ...
# 95                              True              0.540667
# 96                             False                   0.7
# 97                             False              0.733333
# 98                             False               0.57604
# 99                              True              0.538667
#
#                hdi_rope_decision_correct pitg_decision_iteration pitg_accept  \
# experiment_idx
# 0                                   True                     593       False
# 1                                   True                     584       False
# 2                                   True                     592       False
# 3                                   True                     584       False
# 4                                   True                     575       False
# ...                                  ...                     ...         ...
# 95                                 False                     594       False
# 96                                  True                     596       False
# 97                                  True                     587       False
# 98                                  True                     587       False
# 99                                 False                     594       False
#
#                pitg_reject_below  ... pitg_inconclusive pitg_success_rate  \
# experiment_idx                    ...
# 0                          False  ...              True           0.55312
# 1                          False  ...              True          0.578767
# 2                          False  ...              True          0.554054
# 3                          False  ...              True          0.578767
# 4                          False  ...             False          0.601739
# ...                          ...  ...               ...               ...
# 95                         False  ...              True          0.548822
# 96                         False  ...              True          0.538591
# 97                         False  ...              True          0.572402
# 98                         False  ...              True          0.570698
# 99                         False  ...              True          0.548822
#
#                pitg_decision_correct epitg_decision_iteration epitg_accept  \
# experiment_idx
# 0                               True                     1500        False
# 1                               True                     1500        False
# 2                               True                     1500        False
# 3                               True                      834        False
# 4                               True                      575        False
# ...                              ...                      ...          ...
# 95                             False                     1500        False
# 96                             False                     1500        False
# 97                              True                     1500        False
# 98                              True                     1394        False
# 99                             False                     1500        False
#
#                epitg_reject_below epitg_reject_above epitg_inconclusive  \
# experiment_idx
# 0                           False              False               True
# 1                           False              False               True
# 2                           False              False               True
# 3                           False               True              False
# 4                           False               True              False
# ...                           ...                ...                ...
# 95                          False              False               True
# 96                          False              False               True
# 97                          False              False               True
# 98                          False               True              False
# 99                          False              False               True
#
#                epitg_success_rate epitg_decision_correct
# experiment_idx
# 0                            0.56                   True
# 1                        0.568667                   True
# 2                        0.572667                   True
# 3                        0.583933                   True
# 4                        0.601739                   True
# ...                           ...                    ...
# 95                       0.540667                  False
# 96                       0.557333                   True
# 97                          0.566                   True
# 98                        0.57604                   True
# 99                       0.538667                  False
#
# [100 rows x 21 columns]

# %%
hypothesis_.df_experiment_correctness[['hdi_rope_decision_correct', 'pitg_decision_correct', 'epitg_decision_correct']]
# Out:
#                hdi_rope_decision_correct pitg_decision_correct  \
# experiment_idx
# 0                                   True                  True
# 1                                   True                  True
# 2                                   True                  True
# 3                                   True                  True
# 4                                   True                  True
# ...                                  ...                   ...
# 95                                 False                 False
# 96                                  True                 False
# 97                                  True                  True
# 98                                  True                  True
# 99                                 False                 False
#
#                epitg_decision_correct
# experiment_idx
# 0                                True
# 1                                True
# 2                                True
# 3                                True
# 4                                True
# ...                               ...
# 95                              False
# 96                               True
# 97                               True
# 98                               True
# 99                              False
#
# [100 rows x 3 columns]

# %%
hypothesis_.df_experiment_correctness[['hdi_rope_inconclusive', 'pitg_inconclusive', 'epitg_inconclusive']].astype(int).mean()
# Out:
# hdi_rope_inconclusive    0.42
# pitg_inconclusive        0.80
# epitg_inconclusive       0.53
# dtype: float64

# %%
hypothesis_.df_experiment_correctness[['hdi_rope_decision_correct', 'pitg_decision_correct', 'epitg_decision_correct']].astype(int).mean()
# Out:
# hdi_rope_decision_correct    0.95
# pitg_decision_correct        0.79
# epitg_decision_correct       0.93
# dtype: float64

# %%
df_correctness_pitg_inc = hypothesis_.df_experiment_correctness.query("pitg_inconclusive == True")

df_correctness_pitg_inc[['hdi_rope_inconclusive', 'pitg_inconclusive', 'epitg_inconclusive']].astype(int).mean()
# Out:
# hdi_rope_inconclusive    0.5250
# pitg_inconclusive        1.0000
# epitg_inconclusive       0.6625
# dtype: float64

# %%
df_correctness_pitg_inc[['hdi_rope_decision_correct', 'pitg_decision_correct', 'epitg_decision_correct']].astype(int).mean()
# Out:
# hdi_rope_decision_correct    0.9375
# pitg_decision_correct        0.7375
# epitg_decision_correct       0.9125
# dtype: float64

# %%
aa = None
bool(aa) if aa is not None else aa

# %%
method_stats
# Out:
# {'pitg': {0: {'decision_iteration': 593,
#    'accept': False,
#    'reject_below': False,
#    'reject_above': False,
#    'conclusive': False,
#    'inconclusive': True,
#    'successes': 328,
#    'failures': 265,
#    'hdi_min': 0.5131058955630885,
#    'hdi_max': 0.5930386826397187,
#    'precision_goal_achieved': True},
#   1: {'decision_iteration': 584,
#    'accept': False,
#    'reject_below': False,
#    'reject_above': False,
#    'conclusive': False,
#    'inconclusive': True,
#    'successes': 338,
#    'failures': 246,
#    'hdi_min': 0.538693608192975,
#    'hdi_max': 0.61868303981102,
#    'precision_goal_achieved': True},
#   2: {'decision_iteration': 592,
#    'accept': False,
#    'reject_below': False,
#    'reject_above': False,
#    'conclusive': False,
#    'inconclusive': True,
#    'successes': 328,
#    'failures': 264,
#    'hdi_min': 0.5139978978511637,
#    'hdi_max': 0.5939817426861769,
#    'precision_goal_achieved': True}},
#  'epitg': {0: {'decision_iteration': 1500,
#    'accept': False,
#    'reject_below': False,
#    'reject_above': False,
#    'conclusive': False,
#    'inconclusive': True,
#    'successes': 840,
#    'failures': 660,
#    'hdi_min': 0.534867547044455,
#    'hdi_max': 0.5850835156227976,
#    'precision_goal_achieved': True},
#   1: {'decision_iteration': 1500,
#    'accept': False,
#    'reject_below': False,
#    'reject_above': False,
#    'conclusive': False,
#    'inconclusive': True,
#    'successes': 853,
#    'failures': 647,
#    'hdi_min': 0.5435971864178839,
#    'hdi_max': 0.5936992132066574,
#    'precision_goal_achieved': True},
#   2: {'decision_iteration': 1500,
#    'accept': False,
#    'reject_below': False,
#    'reject_above': False,
#    'conclusive': False,
#    'inconclusive': True,
#    'successes': 859,
#    'failures': 641,
#    'hdi_min': 0.5476209931234249,
#    'hdi_max': 0.597665145471056,
#    'precision_goal_achieved': True}},
#  'hdi_rope': {0: {'decision_iteration': 1500,
#    'accept': False,
#    'reject_below': False,
#    'reject_above': False,
#    'conclusive': False,
#    'inconclusive': True,
#    'successes': 840,
#    'failures': 660,
#    'hdi_min': 0.534867547044455,
#    'hdi_max': 0.5850835156227976,
#    'precision_goal_achieved': True},
#   1: {'decision_iteration': 1500,
#    'accept': False,
#    'reject_below': False,
#    'reject_above': False,
#    'conclusive': False,
#    'inconclusive': True,
#    'successes': 853,
#    'failures': 647,
#    'hdi_min': 0.5435971864178839,
#    'hdi_max': 0.5936992132066574,
#    'precision_goal_achieved': True},
#   2: {'decision_iteration': 1500,
#    'accept': False,
#    'reject_below': False,
#    'reject_above': False,
#    'conclusive': False,
#    'inconclusive': True,
#    'successes': 859,
#    'failures': 641,
#    'hdi_min': 0.5476209931234249,
#    'hdi_max': 0.597665145471056,
#    'precision_goal_achieved': True}}}
